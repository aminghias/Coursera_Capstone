# %%
# !pip install pandas
# !pip install requests
# !pip install bs4
# !pip install plotly
# !pip install geopy
# Out:
# Requirement already satisfied: pandas in c:\users\amin\anaconda3\lib\site-packages (1.1.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\amin\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\amin\anaconda3\lib\site-packages (from pandas) (1.19.2)
# Requirement already satisfied: pytz>=2017.2 in c:\users\amin\anaconda3\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: six>=1.5 in c:\users\amin\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: requests in c:\users\amin\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\amin\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amin\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\amin\anaconda3\lib\site-packages (from requests) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\amin\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: bs4 in c:\users\amin\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\amin\anaconda3\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\amin\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.0.1)
# Requirement already satisfied: plotly in c:\users\amin\anaconda3\lib\site-packages (4.14.3)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\amin\anaconda3\lib\site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in c:\users\amin\anaconda3\lib\site-packages (from plotly) (1.15.0)
# Requirement already satisfied: geopy in c:\users\amin\anaconda3\lib\site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\amin\anaconda3\lib\site-packages (from geopy) (1.50)

# %%
#  Import Libraries


from bs4 import BeautifulSoup

import geopy

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
# from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
df = pd.read_csv ('https://opendata.com.pk/dataset/9e959916-1cfc-4e28-85c8-f10ff63e5df2/resource/8c882a14-ee3f-4534-a15f-5fec2319d5e5/download/zameen-updated.csv')
df.head()
# Out:
#    property_id  location_id  \
# 0       237062         3325
# 1       346905         3236
# 2       386513          764
# 3       656161          340
# 4       841645         3226
#
#                                             page_url property_type     price  \
# 0  https://www.zameen.com/Property/g_10_g_10_2_gr...          Flat  10000000
# 1  https://www.zameen.com/Property/e_11_2_service...          Flat   6900000
# 2  https://www.zameen.com/Property/islamabad_g_15...         House  16500000
# 3  https://www.zameen.com/Property/islamabad_bani...         House  43500000
# 4  https://www.zameen.com/Property/dha_valley_dha...         House   7000000
#
#       location       city      province_name   latitude  longitude  baths  \
# 0         G-10  Islamabad  Islamabad Capital  33.679890  73.012640      2
# 1         E-11  Islamabad  Islamabad Capital  33.700993  72.971492      3
# 2         G-15  Islamabad  Islamabad Capital  33.631486  72.926559      6
# 3    Bani Gala  Islamabad  Islamabad Capital  33.707573  73.151199      4
# 4  DHA Defence  Islamabad  Islamabad Capital  33.492591  73.301339      3
#
#         area   purpose  bedrooms  date_added         agency  \
# 0    4 Marla  For Sale         2  02-04-2019            NaN
# 1  5.6 Marla  For Sale         3  05-04-2019            NaN
# 2    8 Marla  For Sale         5  07-17-2019            NaN
# 3    2 Kanal  For Sale         4  04-05-2019            NaN
# 4    8 Marla  For Sale         3  07-10-2019  Easy Property
#
#                                           agent Area Type  Area Size  \
# 0                                           NaN     Marla        4.0
# 1                                           NaN     Marla        5.6
# 2                                           NaN     Marla        8.0
# 3                                           NaN     Kanal        2.0
# 4  Muhammad Junaid Ceo Muhammad Shahid Director     Marla        8.0
#
#   Area Category
# 0     0-5 Marla
# 1    5-10 Marla
# 2    5-10 Marla
# 3     1-5 Kanal
# 4    5-10 Marla

# %%
# Using location that are of Karachi only

df=df[df['city'].str.contains('Karachi')]
df.head()
# Out:
#      property_id  location_id  \
# 156        86575         6649
# 157       342005          232
# 158       466607         1484
# 159       678919         9594
# 160       813506         6732
#
#                                               page_url property_type  \
# 156  https://www.zameen.com/Property/faisal_cantonm...         House
# 157  https://www.zameen.com/Property/karachi_gulist...         House
# 158  https://www.zameen.com/Property/d_h_a_dha_phas...          Flat
# 159  https://www.zameen.com/Property/malir_malir_ka...         House
# 160  https://www.zameen.com/Property/surjani_town_s...         House
#
#          price           location     city province_name   latitude  \
# 156  450000000              Cantt  Karachi         Sindh  24.889395
# 157   35000000  Gulistan-e-Jauhar  Karachi         Sindh  24.914988
# 158   21000000        DHA Defence  Karachi         Sindh  24.814367
# 159    6500000              Malir  Karachi         Sindh  24.882302
# 160   13000000         Gadap Town  Karachi         Sindh  25.018156
#
#      longitude  baths       area   purpose  bedrooms  date_added  \
# 156  67.098627      7    4 Kanal  For Sale         6  06-20-2019
# 157  67.138702      8   16 Marla  For Sale         6  07-18-2019
# 158  67.072083      3  8.9 Marla  For Sale         3  10-20-2018
# 159  67.184677      1  3.2 Marla  For Sale         2  03-10-2019
# 160  67.066864      4  9.6 Marla  For Sale         4  07-18-2019
#
#                  agency           agent Area Type  Area Size Area Category
# 156  Premier Properties  Aamir Motiwala     Kanal        4.0     1-5 Kanal
# 157                 NaN             NaN     Marla       16.0   15-20 Marla
# 158                 NaN             NaN     Marla        8.9    5-10 Marla
# 159                 NaN             NaN     Marla        3.2     0-5 Marla
# 160                 NaN             NaN     Marla        9.6    5-10 Marla

# %%
df.shape
# Out:
# (60484, 20)

# %%
# Forming a new dataframe with our desired parameters 

data=df[['property_type','price','location','city','latitude','longitude','Area Size','bedrooms']].copy()
data.head()
# Out:
#     property_type      price           location     city   latitude  \
# 156         House  450000000              Cantt  Karachi  24.889395
# 157         House   35000000  Gulistan-e-Jauhar  Karachi  24.914988
# 158          Flat   21000000        DHA Defence  Karachi  24.814367
# 159         House    6500000              Malir  Karachi  24.882302
# 160         House   13000000         Gadap Town  Karachi  25.018156
#
#      longitude  Area Size  bedrooms
# 156  67.098627        4.0         6
# 157  67.138702       16.0         6
# 158  67.072083        8.9         3
# 159  67.184677        3.2         2
# 160  67.066864        9.6         4

# %%
# Converting datatype to float

df['price']=df['price'].astype(float)
df['latitude']=df['latitude'].astype(float)
df['longitude']=df['longitude'].astype(float)
df['Area Size']=df['Area Size'].astype(float)

# %%
#  Modifying data as per need

grouped_multiple = df.groupby(['property_type','location','city']).agg({'latitude': ['mean'],'longitude': ['mean'],'price': ['mean', 'min', 'max'],'Area Size': ['mean', 'min', 'max'],'bedrooms':['mean', 'min', 'max','count']})
grouped_multiple.columns = ['mean_latitude','mean_longitude','price_mean', 'price_min', 'price_max','area_mean', 'are_min', 'area_max','bedroom_mean','bedroom_min','bedroom_max','total_houses']
grouped_multiple = grouped_multiple.reset_index()

grouped_multiple.head()
# Out:
#   property_type             location     city  mean_latitude  mean_longitude  \
# 0    Farm House  Bahria Town Karachi  Karachi      24.991752       67.255541
# 1    Farm House       Bin Qasim Town  Karachi      24.865622       67.284917
# 2    Farm House     DHA City Karachi  Karachi      25.015873       67.418095
# 3    Farm House          DHA Defence  Karachi      24.819653       67.077749
# 4    Farm House                Damba  Karachi      24.972520       67.259372
#
#      price_mean   price_min    price_max  area_mean  are_min  area_max  \
# 0  6.273810e+07  25000000.0  140000000.0   9.409524      6.0      19.4
# 1  3.003625e+07     20000.0  120000000.0  17.000000     12.0      20.0
# 2  3.457357e+07     15000.0   70000000.0   4.142857      2.0       7.0
# 3  2.500000e+04     25000.0      25000.0   7.000000      7.0       7.0
# 4  3.650000e+04     28000.0      45000.0   8.000000      8.0       8.0
#
#    bedroom_mean  bedroom_min  bedroom_max  total_houses
# 0      0.523810            0           11            21
# 1      3.500000            2            5             4
# 2      2.714286            0            4             7
# 3      2.000000            2            2             1
# 4      0.000000            0            0             2

# %%
grouped_multiple.shape
# Out:
# (580, 15)

# %%
df_homes=grouped_multiple

# Removing all farm houses from dataframe
df_homes=df_homes[~df_homes['property_type'].str.contains('Farm House')]

df_homes.head()
# Out:
#    property_type              location     city  mean_latitude  \
# 17          Flat    ASF Housing Scheme  Karachi      24.937917
# 18          Flat             ASF Tower  Karachi      24.951961
# 19          Flat   Abdullah Ahmed Road  Karachi      24.891224
# 20          Flat  Abdullah Haroon Road  Karachi      24.848067
# 21          Flat             Abid Town  Karachi      24.927597
#
#     mean_longitude    price_mean   price_min   price_max  area_mean  are_min  \
# 17       67.153712  3.885333e+06   2800000.0   5800000.0   4.366667      3.8
# 18       67.158682  5.461538e+06   1700000.0   8500000.0   5.992308      2.3
# 19       66.988458  5.000000e+06   5000000.0   5000000.0   5.000000      5.0
# 20       67.031176  3.125000e+07  12500000.0  50000000.0   8.900000      6.7
# 21       67.083332  5.492900e+06     23000.0  13000000.0   5.040000      4.0
#
#     area_max  bedroom_mean  bedroom_min  bedroom_max  total_houses
# 17       5.1      2.666667            2            4             3
# 18       8.9      2.538462            0            6            13
# 19       5.0      0.000000            0            0             1
# 20      11.1      3.500000            3            4             2
# 21       7.1      2.400000            0            3            10

# %%
#  Selecting only houses in our dataframe

df_homes=df_homes[df_homes['property_type'].str.contains('House')]
df_homes=df_homes.reset_index()
df_homes.head()
# Out:
#    index property_type                                    location     city  \
# 0    185         House  APP Employees Co-operative Housing Society  Karachi
# 1    186         House                          ASF Housing Scheme  Karachi
# 2    187         House                         Abdullah Ahmed Road  Karachi
# 3    188         House                        Abdullah Haroon Road  Karachi
# 4    189         House                                   Abid Town  Karachi
#
#    mean_latitude  mean_longitude    price_mean   price_min    price_max  \
# 0      24.928572       67.157725  3.900000e+07  39000000.0   39000000.0
# 1      24.937917       67.153713  7.000000e+06   7000000.0    7000000.0
# 2      24.891224       66.988458  6.645000e+07   2900000.0  130000000.0
# 3      24.847829       67.031185  1.088000e+07    400000.0   30000000.0
# 4      24.924261       67.082496  1.493257e+07     28000.0   28000000.0
#
#    area_mean  are_min  area_max  bedroom_mean  bedroom_min  bedroom_max  \
# 0      16.00     16.0      16.0      8.000000            8            8
# 1       4.80      4.8       4.8      4.000000            4            4
# 2       3.00      1.0       5.0      2.500000            0            5
# 3       8.36      1.0      16.0      4.200000            2            7
# 4       4.80      1.8       9.6      4.714286            1           11
#
#    total_houses
# 0             2
# 1             1
# 2             2
# 3             5
# 4             7

# %%
# dropping index column

df_homes=df_homes.drop(['index'],axis=1)

# %%
df_homes.head()
# Out:
#   property_type                                    location     city  \
# 0         House  APP Employees Co-operative Housing Society  Karachi
# 1         House                          ASF Housing Scheme  Karachi
# 2         House                         Abdullah Ahmed Road  Karachi
# 3         House                        Abdullah Haroon Road  Karachi
# 4         House                                   Abid Town  Karachi
#
#    mean_latitude  mean_longitude    price_mean   price_min    price_max  \
# 0      24.928572       67.157725  3.900000e+07  39000000.0   39000000.0
# 1      24.937917       67.153713  7.000000e+06   7000000.0    7000000.0
# 2      24.891224       66.988458  6.645000e+07   2900000.0  130000000.0
# 3      24.847829       67.031185  1.088000e+07    400000.0   30000000.0
# 4      24.924261       67.082496  1.493257e+07     28000.0   28000000.0
#
#    area_mean  are_min  area_max  bedroom_mean  bedroom_min  bedroom_max  \
# 0      16.00     16.0      16.0      8.000000            8            8
# 1       4.80      4.8       4.8      4.000000            4            4
# 2       3.00      1.0       5.0      2.500000            0            5
# 3       8.36      1.0      16.0      4.200000            2            7
# 4       4.80      1.8       9.6      4.714286            1           11
#
#    total_houses
# 0             2
# 1             1
# 2             2
# 3             5
# 4             7

# %%
df_homes.shape
# Out:
# (160, 15)

# %%
# convert an address into latitude and longitude values

address = 'Karachi, KHI'

geolocator = Nominatim(user_agent="karachi_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Karachi are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Karachi are 24.9014311, 67.15934789666397.

# %%
# create map of Karachi using latitude and longitude values
map_karachi = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, location in zip(df_homes['mean_latitude'], df_homes['mean_longitude'], df_homes['location']):
    label = '{}'.format(location)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_karachi)  
    
map_karachi
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_83c6dc5bf1a54de69402bfbdc0769433%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_83c6dc5bf1a54de69402bfbdc0769433%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_83c6dc5bf1a54de69402bfbdc0769433%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_83c6dc5bf1a54de69402bfbdc0769433%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B24.9014311%2C67.15934789666397%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%2 ...

# %%
#  FourSquare credntials

CLIENT_ID = 'RGW4SIWSLHM1ARZ04AKEVOSTH2451TPTLUZPTNRV5P541QCY' # your Foursquare ID
CLIENT_SECRET = '4ASACGFVZ03ESPLD1J4NLHNU0EAXYP14DWQCGZ40VZTX2FJ4' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: RGW4SIWSLHM1ARZ04AKEVOSTH2451TPTLUZPTNRV5P541QCY
# CLIENT_SECRET:4ASACGFVZ03ESPLD1J4NLHNU0EAXYP14DWQCGZ40VZTX2FJ4

# %%
neighborhood_latitude = df_homes.loc[0, 'mean_latitude'] # neighborhood latitude value
neighborhood_longitude = df_homes.loc[0, 'mean_longitude'] # neighborhood longitude value

neighborhood_name = df_homes.loc[0, 'location'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of APP Employees Co-operative Housing Society are 24.928572, 67.157725.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 500 # define radius

 # create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=RGW4SIWSLHM1ARZ04AKEVOSTH2451TPTLUZPTNRV5P541QCY&client_secret=4ASACGFVZ03ESPLD1J4NLHNU0EAXYP14DWQCGZ40VZTX2FJ4&v=20180605&ll=24.928572,67.157725&radius=500&limit=100'

# %%
# Extracting results fron Foursquare

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60c769c1abacf210907a3b89'},
#  'response': {'warning': {'text': "There aren't a lot of results near you. Try something more general, reset your filters, or expand the search area."},
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'totalResults': 1,
#   'suggestedBounds': {'ne': {'lat': 24.933072004500005,
#     'lng': 67.16267805950979},
#    'sw': {'lat': 24.924071995499993, 'lng': 67.15277194049021}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58af240e0037eb2c41d72797',
#        'name': "Saien's Chai",
#        'location': {'address': 'Pink Residency',
#         'crossStreet': 'Gulistan e johar Block-8',
#         'lat': 24.92731,
#         'lng': 67.160069,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 24.92731,
#           'lng': 67.160069}],
#         'distance': 275,
#         'cc': 'PK',
#         'city': 'کراچی',
#         'state': 'سندھ',
#         'country': 'پاکستان',
#         'formattedAddress': ['Pink Residency (Gulistan e johar Block-8)',
#          'کراچی',
#          'پاکستان']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58af240e0037eb2c41d72797-0'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# <ipython-input-22-561c05f0fdd1>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venues = json_normalize(venues) # flatten JSON
#            name   categories       lat        lng
# 0  Saien's Chai  Coffee Shop  24.92731  67.160069

# %%
nearby_venues.shape
# Out:
# (1, 4)

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 1 venues were returned by Foursquare.

# %%
# Making a function to get nearby venuues


def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
karachi_venues = getNearbyVenues(names=df_homes['location'],
                                   latitudes=df_homes['mean_latitude'],
                                   longitudes=df_homes['mean_longitude']
                                  )
# Out:
# APP Employees Co-operative Housing Society
# ASF Housing Scheme
# Abdullah Ahmed Road
# Abdullah Haroon Road
# Abid Town
# Abul Hassan Isphani Road
# Airport
# Aisha Manzil
# Al-Hilal Society
# Al-Jadeed Residency
# Al-Manzar Society
# Allama Iqbal Town
# Altaf Hussain Road
# Amil Colony
# Amir Khusro
# Anda Mor Road
# Azam Town
# Bagh-e-Korangi
# Bahria Town Karachi
# Baldia Town
# Baloch Colony
# Bath Island
# Bilal Town
# Bin Qasim Town
# Blue Bell Residency
# Cantt
# Chapal Courtyard
# Chapal Skymark
# Chapal Uptown
# Civil Lines
# Clifton
# Cotton Export Cooperative Housing Society
# Cutchi Memon Cooperative Housing Society
# DHA City Karachi
# DHA Defence
# Dalmia Cement Factory Road
# Darul Aman Society
# Dastgir Colony
# Defence View Society
# Delhi Colony
# Diamond City
# Etawa Society
# Falaknaz Presidency
# Falcon Complex Faisal
# Fazaia Housing Scheme
# Federal B Area
# Gadap Town
# Garden West
# Gizri
# Gizri Road
# Golimar
# Gujjar Chowk
# Gulberg Town
# Gulistan-e-Jauhar
# Gulistan-e-Malir
# Gulshan-e-Areesha
# Gulshan-e-Iqbal Town
# Gulshan-e-Jami
# Gulshan-e-Malir
# Gulshan-e-Millat
# Gulshan-e-Umair
# Gulshan-e-Usman Housing Society
# Guru Mandir Chorangi
# Hassan Goth
# Hawks Bay Scheme 42
# Hill Park
# Hub River Road
# Humaira Town
# I. I. Chundrigar Road
# Intelligence Colony
# Jamaluddin Afghani Road
# Jamshed Road
# Jamshed Town
# Javed Bahria Coopretive Housing Society
# Jinnah Avenue
# KDA Scheme 1
# Kamran Chowrangi
# Karachi Golf City
# Karachi Motorway
# Karachi, Sindh
# Kashmir Colony
# Kashmir Road
# Kemari Town
# Khalid Bin Walid Road
# Khayaban-e-Ittehad Road
# Khuda Ki Basti
# Khudadad Colony
# Korangi
# Korangi Road
# Lalukhet
# Landhi
# Liaquat Avenue
# Liaquatabad
# Lines Area
# Lyari Expressway
# Lyari Town
# MT Khan Road
# Malir
# Malir Housing Scheme 1
# Malir Link To Super Highway
# Manghopir Road
# Mangopir
# Manzoor Colony
# Maskan Chowrangi
# Mauripur Road
# Mehmoodabad
# Muslimabad Society
# National Highway
# Naval Colony
# Naval Housing Scheme
# Navy Housing Scheme Karsaz
# Naya Nazimabad
# Nazimabad
# New Karachi
# North Karachi
# North Nazimabad
# Northern Bypass
# Old Clifton
# Old Ravians Co-Operative Housing Society
# Orangi Town
# Others
# P & T Colony
# PAF Housing Scheme
# PTV Society
# Pakistan Chowk
# Peoples Colony
# Police Society
# Punjab Colony
# Qayyumabad
# Rashid Minhas Road
# Royal Defence Tower
# Rufi Rose Petals
# Saadi Road
# Saddar Town
# Saima Luxury Homes
# Scheme 33
# Scheme 45
# Sea View Apartments
# Shadman 2
# Shah Faisal Town
# Shah Rasool Colony
# Shah Town
# Shaheed Millat Road
# Shahra-e-Faisal
# Shahra-e-Qaideen
# Shahra-e-Usman
# Shahrah-e-Pakistan
# Sindh Industrial Trading Estate (SITE)
# Siraj-ud-Daula Road
# Stadium Road
# State Bank of Pakistan Staff Co-Operative Housing Society
# Suparco Road
# Super Highway
# Surti Muslim Co-Operative Housing Society
# Tariq Road
# Teacher Society
# Tipu Sultan Road
# University Road
# Zamzama
# circular road

# %%
print('There are {} uniques categories.'.format(len(karachi_venues['Venue Category'].unique())))
# Out:
# There are 107 uniques categories.

# %%
print(karachi_venues.shape)
karachi_venues.head(10)
# Out:
# (498, 7)
#                                  Neighborhood  Neighborhood Latitude  \
# 0  APP Employees Co-operative Housing Society              24.928572
# 1                          ASF Housing Scheme              24.937917
# 2                          ASF Housing Scheme              24.937917
# 3                          ASF Housing Scheme              24.937917
# 4                          ASF Housing Scheme              24.937917
# 5                        Abdullah Haroon Road              24.847829
# 6                        Abdullah Haroon Road              24.847829
# 7                        Abdullah Haroon Road              24.847829
# 8                        Abdullah Haroon Road              24.847829
# 9                        Abdullah Haroon Road              24.847829
#
#    Neighborhood Longitude                           Venue  Venue Latitude  \
# 0               67.157725                    Saien's Chai       24.927310
# 1               67.153713                      Bin Hashim       24.938233
# 2               67.153713  Muslim Pharmacy & Super Market       24.938128
# 3               67.153713          Al-Ghazi Foods Tonight       24.940844
# 4               67.153713          Sindh Green Restaurant       24.939285
# 5               67.031185                      Frere Hall       24.846787
# 6               67.031185                      Suzie Wong       24.846505
# 7               67.031185                    Karachi Club       24.844083
# 8               67.031185                Sind Club Bistro       24.849628
# 9               67.031185                        Marriott       24.846049
#
#    Venue Longitude        Venue Category
# 0        67.160069           Coffee Shop
# 1        67.151470      Department Store
# 2        67.151982         Shopping Mall
# 3        67.153694  Fast Food Restaurant
# 4        67.157438             BBQ Joint
# 5        67.032243         Historic Site
# 6        67.031120      Asian Restaurant
# 7        67.029199           Social Club
# 8        67.031978                Bistro
# 9        67.031186                 Hotel

# %%
# Table is grouped on basis of same Neighborhood

k_count=karachi_venues.groupby('Neighborhood').count()
k_count.head(10)
# Out:
#                                             Neighborhood Latitude  \
# Neighborhood
# APP Employees Co-operative Housing Society                      1
# ASF Housing Scheme                                              4
# Abdullah Haroon Road                                           11
# Abid Town                                                       4
# Abul Hassan Isphani Road                                        2
# Aisha Manzil                                                    2
# Al-Hilal Society                                                1
# Al-Jadeed Residency                                             1
# Allama Iqbal Town                                               4
# Altaf Hussain Road                                              1
#
#                                             Neighborhood Longitude  Venue  \
# Neighborhood
# APP Employees Co-operative Housing Society                       1      1
# ASF Housing Scheme                                               4      4
# Abdullah Haroon Road                                            11     11
# Abid Town                                                        4      4
# Abul Hassan Isphani Road                                         2      2
# Aisha Manzil                                                     2      2
# Al-Hilal Society                                                 1      1
# Al-Jadeed Residency                                              1      1
# Allama Iqbal Town                                                4      4
# Altaf Hussain Road                                               1      1
#
#                                             Venue Latitude  Venue Longitude  \
# Neighborhood
# APP Employees Co-operative Housing Society               1                1
# ASF Housing Scheme                                       4                4
# Abdullah Haroon Road                                    11               11
# Abid Town                                                4                4
# Abul Hassan Isphani Road                                 2                2
# Aisha Manzil                                             2                2
# Al-Hilal Society                                         1                1
# Al-Jadeed Residency                                      1                1
# Allama Iqbal Town                                        4                4
# Altaf Hussain Road                                       1                1
#
#                                             Venue Category
# Neighborhood
# APP Employees Co-operative Housing Society               1
# ASF Housing Scheme                                       4
# Abdullah Haroon Road                                    11
# Abid Town                                                4
# Abul Hassan Isphani Road                                 2
# Aisha Manzil                                             2
# Al-Hilal Society                                         1
# Al-Jadeed Residency                                      1
# Allama Iqbal Town                                        4
# Altaf Hussain Road                                       1

# %%
#  Sorting in descending order based on Venue category

k_count = k_count.sort_values(by ='Venue Category' , ascending=False)
k_count.head(10)
# Out:
#                          Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Siraj-ud-Daula Road                         30                      30     30
# Shah Rasool Colony                          19                      19     19
# Shaheed Millat Road                         17                      17     17
# Jamaluddin Afghani Road                     17                      17     17
# Chapal Skymark                              14                      14     14
# Tipu Sultan Road                            14                      14     14
# Civil Lines                                 14                      14     14
# DHA Defence                                 13                      13     13
# MT Khan Road                                12                      12     12
# Khalid Bin Walid Road                       12                      12     12
#
#                          Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Siraj-ud-Daula Road                  30               30              30
# Shah Rasool Colony                   19               19              19
# Shaheed Millat Road                  17               17              17
# Jamaluddin Afghani Road              17               17              17
# Chapal Skymark                       14               14              14
# Tipu Sultan Road                     14               14              14
# Civil Lines                          14               14              14
# DHA Defence                          13               13              13
# MT Khan Road                         12               12              12
# Khalid Bin Walid Road                12               12              12

# %%
df_c = df_homes

# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
df_c = k_count.join(df_c.set_index('location'), on='Neighborhood')
df_c.head(10)
# Out:
#                          Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Siraj-ud-Daula Road                         30                      30     30
# Shah Rasool Colony                          19                      19     19
# Shaheed Millat Road                         17                      17     17
# Jamaluddin Afghani Road                     17                      17     17
# Chapal Skymark                              14                      14     14
# Tipu Sultan Road                            14                      14     14
# Civil Lines                                 14                      14     14
# DHA Defence                                 13                      13     13
# MT Khan Road                                12                      12     12
# Khalid Bin Walid Road                       12                      12     12
#
#                          Venue Latitude  Venue Longitude  Venue Category  \
# Neighborhood
# Siraj-ud-Daula Road                  30               30              30
# Shah Rasool Colony                   19               19              19
# Shaheed Millat Road                  17               17              17
# Jamaluddin Afghani Road              17               17              17
# Chapal Skymark                       14               14              14
# Tipu Sultan Road                     14               14              14
# Civil Lines                          14               14              14
# DHA Defence                          13               13              13
# MT Khan Road                         12               12              12
# Khalid Bin Walid Road                12               12              12
#
#                         property_type     city  mean_latitude  mean_longitude  \
# Neighborhood
# Siraj-ud-Daula Road             House  Karachi      24.879682       67.068985
# Shah Rasool Colony              House  Karachi      24.810966       67.034833
# Shaheed Millat Road             House  Karachi      24.876831       67.070116
# Jamaluddin Afghani Road         House  Karachi      24.884039       67.064471
# Chapal Skymark                  House  Karachi      24.844343       67.027389
# Tipu Sultan Road                House  Karachi      24.876120       67.085330
# Civil Lines                     House  Karachi      24.845670       67.030077
# DHA Defence                     House  Karachi      24.808753       67.063815
# MT Khan Road                    House  Karachi      24.845752       67.022147
# Khalid Bin Walid Road           House  Karachi      24.874922       67.057322
#
#                            price_mean    price_min    price_max  area_mean  \
# Neighborhood
# Siraj-ud-Daula Road      2.300000e+08  160000000.0  300000000.0   1.400000
# Shah Rasool Colony       9.700000e+07   14000000.0  180000000.0   4.550000
# Shaheed Millat Road      5.389147e+07     255000.0  222000000.0   6.311765
# Jamaluddin Afghani Road  7.000000e+04      70000.0      70000.0   9.600000
# Chapal Skymark           4.250000e+07   42500000.0   42500000.0  10.000000
# Tipu Sultan Road         2.617250e+07      75000.0   82500000.0   5.640000
# Civil Lines              2.958000e+07   24900000.0   38000000.0   8.040000
# DHA Defence              8.094658e+07          1.0  700000000.0   3.541619
# MT Khan Road             6.433333e+06    4000000.0    8300000.0   4.000000
# Khalid Bin Walid Road    4.392111e+07      40000.0  100000000.0  10.155556
#
#                          are_min  area_max  bedroom_mean  bedroom_min  \
# Neighborhood
# Siraj-ud-Daula Road          1.0       1.8      2.000000            0
# Shah Rasool Colony           1.9       7.2      2.500000            0
# Shaheed Millat Road          1.0      16.0      4.529412            0
# Jamaluddin Afghani Road      9.6       9.6      3.000000            3
# Chapal Skymark              10.0      10.0      6.000000            6
# Tipu Sultan Road             1.0      18.0      3.600000            0
# Civil Lines                  6.4      10.7      3.200000            3
# DHA Defence                  1.0      20.0      4.845252            0
# MT Khan Road                 3.2       4.8      3.333333            2
# Khalid Bin Walid Road        1.2      16.0      5.444444            0
#
#                          bedroom_max  total_houses
# Neighborhood
# Siraj-ud-Daula Road                4             2
# Shah Rasool Colony                 5             2
# Shaheed Millat Road               11            17
# Jamaluddin Afghani Road            3             1
# Chapal Skymark                     6             1
# Tipu Sultan Road                   7            10
# Civil Lines                        4             5
# DHA Defence                       15          5286
# MT Khan Road                       5             3
# Khalid Bin Walid Road             10             9

# %%
df_c.plot(x="price_mean", y="Venue Category", kind="scatter")
# Out:
# <AxesSubplot:xlabel='price_mean', ylabel='Venue Category'>

# %%
df_c.plot(x='price_mean', y="area_mean", kind="scatter")
# Out:
# <AxesSubplot:xlabel='price_mean', ylabel='area_mean'>

# %%
df_c.plot(x='price_mean', y="bedroom_mean", kind="scatter")
# Out:
# <AxesSubplot:xlabel='price_mean', ylabel='bedroom_mean'>

# %%
# Grouping dataframe on basis of neighbourhood and venuecategory with its value count

k_grouped=karachi_venues.groupby(['Neighborhood']).agg({'Venue Category': ['value_counts']})

k_grouped.head(20)
# Out:
#                                                                 Venue Category
#                                                                   value_counts
# Neighborhood                               Venue Category
# APP Employees Co-operative Housing Society Coffee Shop                       1
# ASF Housing Scheme                         BBQ Joint                         1
#                                            Department Store                  1
#                                            Fast Food Restaurant              1
#                                            Shopping Mall                     1
# Abdullah Haroon Road                       Café                              2
#                                            Social Club                       2
#                                            Asian Restaurant                  1
#                                            Bakery                            1
#                                            Bistro                            1
#                                            Fast Food Restaurant              1
#                                            Historic Site                     1
#                                            Hotel                             1
#                                            Hotel Pool                        1
# Abid Town                                  BBQ Joint                         1
#                                            Boutique                          1
#                                            Park                              1
#                                            Sporting Goods Shop               1
# Abul Hassan Isphani Road                   Café                              1
#                                            Grocery Store                     1

# %%
#  Unstacking the grouped to find the venue categories as colums

k_df = k_grouped.unstack()
print(k_df.shape)
k_df.tail(10)
# Out:
# (106, 107)
#                                              Venue Category                    \
#                                                value_counts
# Venue Category                            Accessories Store Afghan Restaurant
# Neighborhood
# Shahrah-e-Pakistan                                      NaN               NaN
# Siraj-ud-Daula Road                                     NaN               NaN
# Suparco Road                                            NaN               NaN
# Super Highway                                           NaN               2.0
# Surti Muslim Co-Operative Housing Society               NaN               NaN
# Tariq Road                                              NaN               NaN
# Teacher Society                                         NaN               NaN
# Tipu Sultan Road                                        NaN               NaN
# University Road                                         NaN               NaN
# Zamzama                                                 NaN               NaN
#
#                                                               \
#
# Venue Category                            African Restaurant
# Neighborhood
# Shahrah-e-Pakistan                                       NaN
# Siraj-ud-Daula Road                                      NaN
# Suparco Road                                             NaN
# Super Highway                                            NaN
# Surti Muslim Co-Operative Housing Society                NaN
# Tariq Road                                               NaN
# Teacher Society                                          NaN
# Tipu Sultan Road                                         NaN
# University Road                                          NaN
# Zamzama                                                  NaN
#
#                                                                \
#
# Venue Category                            American Restaurant
# Neighborhood
# Shahrah-e-Pakistan                                        NaN
# Siraj-ud-Daula Road                                       1.0
# Suparco Road                                              NaN
# Super Highway                                             NaN
# Surti Muslim Co-Operative Housing Society                 NaN
# Tariq Road                                                NaN
# Teacher Society                                           NaN
# Tipu Sultan Road                                          NaN
# University Road                                           NaN
# Zamzama                                                   NaN
#
#                                                                                \
#
# Venue Category                            Asian Restaurant Athletics & Sports
# Neighborhood
# Shahrah-e-Pakistan                                     NaN                NaN
# Siraj-ud-Daula Road                                    NaN                NaN
# Suparco Road                                           NaN                NaN
# Super Highway                                          NaN                NaN
# Surti Muslim Co-Operative Housing Society              NaN                NaN
# Tariq Road                                             NaN                NaN
# Teacher Society                                        NaN                NaN
# Tipu Sultan Road                                       NaN                NaN
# University Road                                        NaN                NaN
# Zamzama                                                NaN                NaN
#
#                                                                           \
#
# Venue Category                            Auto Workshop BBQ Joint Bakery
# Neighborhood
# Shahrah-e-Pakistan                                  NaN       NaN    3.0
# Siraj-ud-Daula Road                                 NaN       2.0    NaN
# Suparco Road                                        NaN       1.0    NaN
# Super Highway                                       NaN       NaN    NaN
# Surti Muslim Co-Operative Housing Society           NaN       NaN    NaN
# Tariq Road                                          NaN       2.0    NaN
# Teacher Society                                     NaN       NaN    NaN
# Tipu Sultan Road                                    NaN       NaN    1.0
# University Road                                     NaN       NaN    NaN
# Zamzama                                             NaN       1.0    NaN
#
#                                                                            \
#
# Venue Category                            Beach Bistro Bookstore Boutique
# Neighborhood
# Shahrah-e-Pakistan                          NaN    NaN       NaN      NaN
# Siraj-ud-Daula Road                         NaN    NaN       NaN      NaN
# Suparco Road                                NaN    NaN       NaN      NaN
# Super Highway                               NaN    NaN       NaN      NaN
# Surti Muslim Co-Operative Housing Society   NaN    NaN       NaN      NaN
# Tariq Road                                  NaN    NaN       NaN      NaN
# Teacher Society                             NaN    NaN       NaN      NaN
# Tipu Sultan Road                            NaN    NaN       NaN      NaN
# University Road                             NaN    NaN       NaN      NaN
# Zamzama                                     NaN    NaN       NaN      NaN
#
#                                                                         \
#
# Venue Category                            Bowling Alley Breakfast Spot
# Neighborhood
# Shahrah-e-Pakistan                                  NaN            NaN
# Siraj-ud-Daula Road                                 1.0            1.0
# Suparco Road                                        NaN            NaN
# Super Highway                                       NaN            NaN
# Surti Muslim Co-Operative Housing Society           NaN            NaN
# Tariq Road                                          NaN            NaN
# Teacher Society                                     NaN            NaN
# Tipu Sultan Road                                    NaN            NaN
# University Road                                     NaN            NaN
# Zamzama                                             NaN            NaN
#
#                                                                     \
#
# Venue Category                            Burger Joint Bus Station
# Neighborhood
# Shahrah-e-Pakistan                                 1.0         NaN
# Siraj-ud-Daula Road                                2.0         NaN
# Suparco Road                                       NaN         NaN
# Super Highway                                      NaN         NaN
# Surti Muslim Co-Operative Housing Society          NaN         NaN
# Tariq Road                                         NaN         NaN
# Teacher Society                                    NaN         NaN
# Tipu Sultan Road                                   NaN         NaN
# University Road                                    NaN         NaN
# Zamzama                                            NaN         NaN
#
#                                                                              \
#
# Venue Category                            Business Service Café Candy Store
# Neighborhood
# Shahrah-e-Pakistan                                     NaN  NaN         NaN
# Siraj-ud-Daula Road                                    NaN  1.0         NaN
# Suparco Road                                           NaN  NaN         NaN
# Super Highway                                          NaN  NaN         NaN
# Surti Muslim Co-Operative Housing Society              NaN  NaN         NaN
# Tariq Road                                             NaN  NaN         NaN
# Teacher Society                                        NaN  NaN         1.0
# Tipu Sultan Road                                       NaN  1.0         NaN
# University Road                                        NaN  NaN         NaN
# Zamzama                                                NaN  NaN         NaN
#
#                                                                              \
#
# Venue Category                            Chinese Restaurant Clothing Store
# Neighborhood
# Shahrah-e-Pakistan                                       NaN            NaN
# Siraj-ud-Daula Road                                      NaN            NaN
# Suparco Road                                             NaN            NaN
# Super Highway                                            NaN            NaN
# Surti Muslim Co-Operative Housing Society                NaN            NaN
# Tariq Road                                               4.0            NaN
# Teacher Society                                          NaN            NaN
# Tipu Sultan Road                                         NaN            NaN
# University Road                                          NaN            NaN
# Zamzama                                                  NaN            NaN
#
#                                                                          \
#
# Venue Category                            Coffee Shop Convenience Store
# Neighborhood
# Shahrah-e-Pakistan                                NaN               NaN
# Siraj-ud-Daula Road                               1.0               NaN
# Suparco Road                                      NaN               NaN
# Super Highway                                     NaN               NaN
# Surti Muslim Co-Operative Housing Society         NaN               NaN
# Tariq Road                                        NaN               NaN
# Teacher Society                                   NaN               NaN
# Tipu Sultan Road                                  NaN               NaN
# University Road                                   NaN               NaN
# Zamzama                                           2.0               NaN
#
#                                                                          \
#
# Venue Category                            Cosmetics Shop Cricket Ground
# Neighborhood
# Shahrah-e-Pakistan                                   NaN            NaN
# Siraj-ud-Daula Road                                  NaN            NaN
# Suparco Road                                         NaN            NaN
# Super Highway                                        NaN            NaN
# Surti Muslim Co-Operative Housing Society            NaN            NaN
# Tariq Road                                           NaN            NaN
# Teacher Society                                      NaN            NaN
# Tipu Sultan Road                                     NaN            NaN
# University Road                                      1.0            NaN
# Zamzama                                              NaN            NaN
#
#                                                                                \
#
# Venue Category                            Department Store Dessert Shop Diner
# Neighborhood
# Shahrah-e-Pakistan                                     2.0          NaN   NaN
# Siraj-ud-Daula Road                                    2.0          NaN   NaN
# Suparco Road                                           NaN          NaN   NaN
# Super Highway                                          NaN          NaN   NaN
# Surti Muslim Co-Operative Housing Society              NaN          NaN   NaN
# Tariq Road                                             NaN          1.0   NaN
# Teacher Society                                        NaN          NaN   NaN
# Tipu Sultan Road                                       1.0          NaN   NaN
# University Road                                        NaN          NaN   NaN
# Zamzama                                                NaN          NaN   1.0
#
#                                                                         \
#
# Venue Category                            Donut Shop Electronics Store
# Neighborhood
# Shahrah-e-Pakistan                               NaN               NaN
# Siraj-ud-Daula Road                              NaN               NaN
# Suparco Road                                     NaN               NaN
# Super Highway                                    NaN               NaN
# Surti Muslim Co-Operative Housing Society        NaN               NaN
# Tariq Road                                       NaN               NaN
# Teacher Society                                  NaN               NaN
# Tipu Sultan Road                                 NaN               NaN
# University Road                                  NaN               NaN
# Zamzama                                          NaN               NaN
#
#                                                                    \
#
# Venue Category                            English Restaurant Farm
# Neighborhood
# Shahrah-e-Pakistan                                       NaN  NaN
# Siraj-ud-Daula Road                                      NaN  NaN
# Suparco Road                                             NaN  NaN
# Super Highway                                            NaN  NaN
# Surti Muslim Co-Operative Housing Society                NaN  NaN
# Tariq Road                                               NaN  NaN
# Teacher Society                                          NaN  NaN
# Tipu Sultan Road                                         NaN  NaN
# University Road                                          NaN  NaN
# Zamzama                                                  NaN  NaN
#
#                                                                             \
#
# Venue Category                            Fast Food Restaurant Flea Market
# Neighborhood
# Shahrah-e-Pakistan                                         1.0         NaN
# Siraj-ud-Daula Road                                        2.0         NaN
# Suparco Road                                               NaN         NaN
# Super Highway                                              NaN         NaN
# Surti Muslim Co-Operative Housing Society                  NaN         NaN
# Tariq Road                                                 2.0         NaN
# Teacher Society                                            NaN         NaN
# Tipu Sultan Road                                           3.0         NaN
# University Road                                            NaN         NaN
# Zamzama                                                    NaN         NaN
#
#                                                                                \
#
# Venue Category                            Food & Drink Shop Food Court Forest
# Neighborhood
# Shahrah-e-Pakistan                                      NaN        NaN    NaN
# Siraj-ud-Daula Road                                     3.0        NaN    NaN
# Suparco Road                                            NaN        NaN    NaN
# Super Highway                                           NaN        NaN    NaN
# Surti Muslim Co-Operative Housing Society               NaN        NaN    NaN
# Tariq Road                                              NaN        NaN    NaN
# Teacher Society                                         NaN        NaN    NaN
# Tipu Sultan Road                                        NaN        NaN    NaN
# University Road                                         NaN        NaN    NaN
# Zamzama                                                 NaN        NaN    NaN
#
#                                                              \
#
# Venue Category                            French Restaurant
# Neighborhood
# Shahrah-e-Pakistan                                      NaN
# Siraj-ud-Daula Road                                     NaN
# Suparco Road                                            NaN
# Super Highway                                           NaN
# Surti Muslim Co-Operative Housing Society               NaN
# Tariq Road                                              NaN
# Teacher Society                                         NaN
# Tipu Sultan Road                                        NaN
# University Road                                         NaN
# Zamzama                                                 NaN
#
#                                                                \
#
# Venue Category                            Fried Chicken Joint
# Neighborhood
# Shahrah-e-Pakistan                                        NaN
# Siraj-ud-Daula Road                                       NaN
# Suparco Road                                              NaN
# Super Highway                                             NaN
# Surti Muslim Co-Operative Housing Society                 NaN
# Tariq Road                                                NaN
# Teacher Society                                           NaN
# Tipu Sultan Road                                          NaN
# University Road                                           NaN
# Zamzama                                                   NaN
#
#                                                               \
#
# Venue Category                            Frozen Yogurt Shop
# Neighborhood
# Shahrah-e-Pakistan                                       NaN
# Siraj-ud-Daula Road                                      NaN
# Suparco Road                                             NaN
# Super Highway                                            NaN
# Surti Muslim Co-Operative Housing Society                NaN
# Tariq Road                                               NaN
# Teacher Society                                          NaN
# Tipu Sultan Road                                         1.0
# University Road                                          NaN
# Zamzama                                                  NaN
#
#                                                                               \
#
# Venue Category                            Furniture / Home Store Gaming Cafe
# Neighborhood
# Shahrah-e-Pakistan                                           NaN         NaN
# Siraj-ud-Daula Road                                          NaN         NaN
# Suparco Road                                                 NaN         NaN
# Super Highway                                                NaN         NaN
# Surti Muslim Co-Operative Housing Society                    NaN         NaN
# Tariq Road                                                   NaN         NaN
# Teacher Society                                              NaN         NaN
# Tipu Sultan Road                                             NaN         NaN
# University Road                                              NaN         NaN
# Zamzama                                                      NaN         NaN
#
#                                                                               \
#
# Venue Category                            Gas Station Gastropub Gourmet Shop
# Neighborhood
# Shahrah-e-Pakistan                                NaN       NaN          NaN
# Siraj-ud-Daula Road                               NaN       NaN          NaN
# Suparco Road                                      NaN       NaN          NaN
# Super Highway                                     NaN       NaN          NaN
# Surti Muslim Co-Operative Housing Society         NaN       NaN          NaN
# Tariq Road                                        NaN       NaN          NaN
# Teacher Society                                   NaN       NaN          NaN
# Tipu Sultan Road                                  NaN       NaN          1.0
# University Road                                   NaN       NaN          NaN
# Zamzama                                           NaN       NaN          NaN
#
#                                                                               \
#
# Venue Category                            Grocery Store Gym Halal Restaurant
# Neighborhood
# Shahrah-e-Pakistan                                  NaN NaN              NaN
# Siraj-ud-Daula Road                                 NaN NaN              NaN
# Suparco Road                                        NaN NaN              NaN
# Super Highway                                       NaN NaN              NaN
# Surti Muslim Co-Operative Housing Society           NaN NaN              NaN
# Tariq Road                                          NaN NaN              NaN
# Teacher Society                                     NaN NaN              NaN
# Tipu Sultan Road                                    NaN NaN              NaN
# University Road                                     NaN NaN              NaN
# Zamzama                                             NaN NaN              NaN
#
#                                                                         \
#
# Venue Category                            Historic Site History Museum
# Neighborhood
# Shahrah-e-Pakistan                                  NaN            NaN
# Siraj-ud-Daula Road                                 NaN            NaN
# Suparco Road                                        NaN            NaN
# Super Highway                                       NaN            NaN
# Surti Muslim Co-Operative Housing Society           NaN            NaN
# Tariq Road                                          NaN            NaN
# Teacher Society                                     NaN            NaN
# Tipu Sultan Road                                    NaN            NaN
# University Road                                     NaN            NaN
# Zamzama                                             NaN            NaN
#
#                                                                          \
#
# Venue Category                            Home Service Hookah Bar Hotel
# Neighborhood
# Shahrah-e-Pakistan                                 NaN        NaN   NaN
# Siraj-ud-Daula Road                                NaN        NaN   NaN
# Suparco Road                                       NaN        NaN   NaN
# Super Highway                                      NaN        NaN   NaN
# Surti Muslim Co-Operative Housing Society          NaN        NaN   NaN
# Tariq Road                                         NaN        1.0   NaN
# Teacher Society                                    NaN        NaN   NaN
# Tipu Sultan Road                                   NaN        1.0   NaN
# University Road                                    NaN        NaN   NaN
# Zamzama                                            NaN        NaN   NaN
#
#                                                                   \
#
# Venue Category                            Hotel Pool IT Services
# Neighborhood
# Shahrah-e-Pakistan                               NaN         NaN
# Siraj-ud-Daula Road                              NaN         NaN
# Suparco Road                                     NaN         NaN
# Super Highway                                    NaN         NaN
# Surti Muslim Co-Operative Housing Society        NaN         NaN
# Tariq Road                                       NaN         NaN
# Teacher Society                                  NaN         NaN
# Tipu Sultan Road                                 NaN         NaN
# University Road                                  NaN         NaN
# Zamzama                                          NaN         NaN
#
#                                                                             \
#
# Venue Category                            Ice Cream Shop Indian Restaurant
# Neighborhood
# Shahrah-e-Pakistan                                   NaN               1.0
# Siraj-ud-Daula Road                                  2.0               NaN
# Suparco Road                                         NaN               NaN
# Super Highway                                        NaN               NaN
# Surti Muslim Co-Operative Housing Society            NaN               NaN
# Tariq Road                                           NaN               NaN
# Teacher Society                                      NaN               NaN
# Tipu Sultan Road                                     NaN               NaN
# University Road                                      NaN               NaN
# Zamzama                                              NaN               NaN
#
#                                                               \
#
# Venue Category                            Italian Restaurant
# Neighborhood
# Shahrah-e-Pakistan                                       NaN
# Siraj-ud-Daula Road                                      NaN
# Suparco Road                                             NaN
# Super Highway                                            NaN
# Surti Muslim Co-Operative Housing Society                NaN
# Tariq Road                                               NaN
# Teacher Society                                          NaN
# Tipu Sultan Road                                         NaN
# University Road                                          NaN
# Zamzama                                                  NaN
#
#                                                                          \
#
# Venue Category                            Japanese Restaurant Juice Bar
# Neighborhood
# Shahrah-e-Pakistan                                        NaN       NaN
# Siraj-ud-Daula Road                                       NaN       NaN
# Suparco Road                                              NaN       NaN
# Super Highway                                             NaN       NaN
# Surti Muslim Co-Operative Housing Society                 NaN       NaN
# Tariq Road                                                NaN       NaN
# Teacher Society                                           NaN       NaN
# Tipu Sultan Road                                          NaN       NaN
# University Road                                           NaN       NaN
# Zamzama                                                   NaN       NaN
#
#                                                              \
#
# Venue Category                            Kids Store Market
# Neighborhood
# Shahrah-e-Pakistan                               NaN    NaN
# Siraj-ud-Daula Road                              NaN    1.0
# Suparco Road                                     NaN    NaN
# Super Highway                                    NaN    NaN
# Surti Muslim Co-Operative Housing Society        NaN    NaN
# Tariq Road                                       NaN    NaN
# Teacher Society                                  NaN    NaN
# Tipu Sultan Road                                 NaN    NaN
# University Road                                  NaN    NaN
# Zamzama                                          NaN    NaN
#
#                                                                     \
#
# Venue Category                            Mediterranean Restaurant
# Neighborhood
# Shahrah-e-Pakistan                                             NaN
# Siraj-ud-Daula Road                                            NaN
# Suparco Road                                                   NaN
# Super Highway                                                  NaN
# Surti Muslim Co-Operative Housing Society                      NaN
# Tariq Road                                                     NaN
# Teacher Society                                                NaN
# Tipu Sultan Road                                               NaN
# University Road                                                NaN
# Zamzama                                                        1.0
#
#                                                        \
#
# Venue Category                            Men's Store
# Neighborhood
# Shahrah-e-Pakistan                                NaN
# Siraj-ud-Daula Road                               NaN
# Suparco Road                                      NaN
# Super Highway                                     NaN
# Surti Muslim Co-Operative Housing Society         NaN
# Tariq Road                                        NaN
# Teacher Society                                   NaN
# Tipu Sultan Road                                  NaN
# University Road                                   NaN
# Zamzama                                           NaN
#
#                                                                      \
#
# Venue Category                            Middle Eastern Restaurant
# Neighborhood
# Shahrah-e-Pakistan                                              NaN
# Siraj-ud-Daula Road                                             NaN
# Suparco Road                                                    NaN
# Super Highway                                                   1.0
# Surti Muslim Co-Operative Housing Society                       NaN
# Tariq Road                                                      NaN
# Teacher Society                                                 NaN
# Tipu Sultan Road                                                NaN
# University Road                                                 NaN
# Zamzama                                                         NaN
#
#                                                              \
#
# Venue Category                            Mobile Phone Shop
# Neighborhood
# Shahrah-e-Pakistan                                      NaN
# Siraj-ud-Daula Road                                     NaN
# Suparco Road                                            NaN
# Super Highway                                           NaN
# Surti Muslim Co-Operative Housing Society               NaN
# Tariq Road                                              NaN
# Teacher Society                                         NaN
# Tipu Sultan Road                                        NaN
# University Road                                         NaN
# Zamzama                                                 NaN
#
#                                                                              \
#
# Venue Category                            Monument / Landmark Movie Theater
# Neighborhood
# Shahrah-e-Pakistan                                        NaN           NaN
# Siraj-ud-Daula Road                                       NaN           NaN
# Suparco Road                                              NaN           NaN
# Super Highway                                             NaN           NaN
# Surti Muslim Co-Operative Housing Society                 NaN           NaN
# Tariq Road                                                NaN           NaN
# Teacher Society                                           NaN           NaN
# Tipu Sultan Road                                          NaN           NaN
# University Road                                           NaN           NaN
# Zamzama                                                   NaN           NaN
#
#                                                                    \
#
# Venue Category                            Moving Target Multiplex
# Neighborhood
# Shahrah-e-Pakistan                                  NaN       NaN
# Siraj-ud-Daula Road                                 NaN       NaN
# Suparco Road                                        NaN       NaN
# Super Highway                                       NaN       NaN
# Surti Muslim Co-Operative Housing Society           NaN       NaN
# Tariq Road                                          NaN       NaN
# Teacher Society                                     NaN       NaN
# Tipu Sultan Road                                    NaN       NaN
# University Road                                     NaN       NaN
# Zamzama                                             NaN       NaN
#
#                                                                              \
#
# Venue Category                            Other Nightlife Outdoor Sculpture
# Neighborhood
# Shahrah-e-Pakistan                                    NaN               NaN
# Siraj-ud-Daula Road                                   NaN               NaN
# Suparco Road                                          NaN               NaN
# Super Highway                                         NaN               NaN
# Surti Muslim Co-Operative Housing Society             NaN               NaN
# Tariq Road                                            NaN               NaN
# Teacher Society                                       NaN               NaN
# Tipu Sultan Road                                      NaN               NaN
# University Road                                       NaN               NaN
# Zamzama                                               NaN               NaN
#
#                                                                      \
#
# Venue Category                            Pakistani Restaurant Park
# Neighborhood
# Shahrah-e-Pakistan                                         NaN  NaN
# Siraj-ud-Daula Road                                        2.0  1.0
# Suparco Road                                               NaN  NaN
# Super Highway                                              NaN  NaN
# Surti Muslim Co-Operative Housing Society                  NaN  NaN
# Tariq Road                                                 1.0  NaN
# Teacher Society                                            NaN  NaN
# Tipu Sultan Road                                           NaN  NaN
# University Road                                            NaN  NaN
# Zamzama                                                    1.0  NaN
#
#                                                                               \
#
# Venue Category                            Performing Arts Venue Perfume Shop
# Neighborhood
# Shahrah-e-Pakistan                                          NaN          NaN
# Siraj-ud-Daula Road                                         NaN          NaN
# Suparco Road                                                NaN          NaN
# Super Highway                                               NaN          NaN
# Surti Muslim Co-Operative Housing Society                   NaN          NaN
# Tariq Road                                                  NaN          NaN
# Teacher Society                                             NaN          NaN
# Tipu Sultan Road                                            NaN          NaN
# University Road                                             NaN          NaN
# Zamzama                                                     NaN          NaN
#
#                                                                            \
#
# Venue Category                            Pharmacy Pizza Place Playground
# Neighborhood
# Shahrah-e-Pakistan                             NaN         NaN        1.0
# Siraj-ud-Daula Road                            NaN         4.0        NaN
# Suparco Road                                   NaN         NaN        NaN
# Super Highway                                  NaN         NaN        NaN
# Surti Muslim Co-Operative Housing Society      NaN         NaN        NaN
# Tariq Road                                     NaN         NaN        NaN
# Teacher Society                                NaN         NaN        NaN
# Tipu Sultan Road                               1.0         2.0        NaN
# University Road                                NaN         NaN        NaN
# Zamzama                                        NaN         NaN        NaN
#
#                                                                       \
#
# Venue Category                            Plaza Restaurant Roof Deck
# Neighborhood
# Shahrah-e-Pakistan                          NaN        NaN       NaN
# Siraj-ud-Daula Road                         NaN        NaN       NaN
# Suparco Road                                NaN        NaN       NaN
# Super Highway                               NaN        NaN       NaN
# Surti Muslim Co-Operative Housing Society   NaN        NaN       NaN
# Tariq Road                                  NaN        NaN       NaN
# Teacher Society                             NaN        NaN       NaN
# Tipu Sultan Road                            NaN        NaN       NaN
# University Road                             NaN        NaN       NaN
# Zamzama                                     NaN        NaN       NaN
#
#                                                                          \
#
# Venue Category                            Sandwich Place Scenic Lookout
# Neighborhood
# Shahrah-e-Pakistan                                   NaN            NaN
# Siraj-ud-Daula Road                                  NaN            NaN
# Suparco Road                                         NaN            NaN
# Super Highway                                        NaN            NaN
# Surti Muslim Co-Operative Housing Society            NaN            NaN
# Tariq Road                                           NaN            NaN
# Teacher Society                                      NaN            NaN
# Tipu Sultan Road                                     1.0            NaN
# University Road                                      NaN            NaN
# Zamzama                                              NaN            NaN
#
#                                                                          \
#
# Venue Category                            Seafood Restaurant Shoe Store
# Neighborhood
# Shahrah-e-Pakistan                                       NaN        NaN
# Siraj-ud-Daula Road                                      NaN        NaN
# Suparco Road                                             NaN        NaN
# Super Highway                                            NaN        NaN
# Surti Muslim Co-Operative Housing Society                NaN        NaN
# Tariq Road                                               NaN        1.0
# Teacher Society                                          NaN        NaN
# Tipu Sultan Road                                         NaN        NaN
# University Road                                          NaN        1.0
# Zamzama                                                  NaN        NaN
#
#                                                                     \
#
# Venue Category                            Shopping Mall Smoke Shop
# Neighborhood
# Shahrah-e-Pakistan                                  NaN        NaN
# Siraj-ud-Daula Road                                 NaN        NaN
# Suparco Road                                        NaN        NaN
# Super Highway                                       NaN        NaN
# Surti Muslim Co-Operative Housing Society           NaN        NaN
# Tariq Road                                          NaN        NaN
# Teacher Society                                     NaN        NaN
# Tipu Sultan Road                                    NaN        NaN
# University Road                                     NaN        NaN
# Zamzama                                             1.0        1.0
#
#                                                                               \
#
# Venue Category                            Snack Place Social Club Soup Place
# Neighborhood
# Shahrah-e-Pakistan                                NaN         NaN        NaN
# Siraj-ud-Daula Road                               2.0         NaN        NaN
# Suparco Road                                      NaN         NaN        NaN
# Super Highway                                     NaN         NaN        NaN
# Surti Muslim Co-Operative Housing Society         NaN         NaN        NaN
# Tariq Road                                        NaN         NaN        NaN
# Teacher Society                                   NaN         NaN        NaN
# Tipu Sultan Road                                  1.0         NaN        NaN
# University Road                                   NaN         NaN        NaN
# Zamzama                                           NaN         NaN        NaN
#
#                                                                     \
#
# Venue Category                             Spa Sporting Goods Shop
# Neighborhood
# Shahrah-e-Pakistan                         NaN                 NaN
# Siraj-ud-Daula Road                        NaN                 NaN
# Suparco Road                               NaN                 NaN
# Super Highway                              NaN                 NaN
# Surti Muslim Co-Operative Housing Society  NaN                 NaN
# Tariq Road                                 NaN                 NaN
# Teacher Society                            NaN                 NaN
# Tipu Sultan Road                           NaN                 NaN
# University Road                            NaN                 NaN
# Zamzama                                    1.0                 NaN
#
#                                                                               \
#
# Venue Category                            Sports Club Steakhouse Supermarket
# Neighborhood
# Shahrah-e-Pakistan                                NaN        NaN         NaN
# Siraj-ud-Daula Road                               NaN        1.0         NaN
# Suparco Road                                      NaN        NaN         NaN
# Super Highway                                     NaN        NaN         NaN
# Surti Muslim Co-Operative Housing Society         NaN        NaN         NaN
# Tariq Road                                        NaN        NaN         NaN
# Teacher Society                                   NaN        NaN         NaN
# Tipu Sultan Road                                  NaN        NaN         NaN
# University Road                                   NaN        NaN         NaN
# Zamzama                                           NaN        NaN         NaN
#
#                                                                         \
#
# Venue Category                            Tailor Shop Tea Room Theater
# Neighborhood
# Shahrah-e-Pakistan                                NaN      NaN     NaN
# Siraj-ud-Daula Road                               NaN      1.0     NaN
# Suparco Road                                      NaN      NaN     NaN
# Super Highway                                     NaN      NaN     NaN
# Surti Muslim Co-Operative Housing Society         NaN      NaN     NaN
# Tariq Road                                        NaN      NaN     NaN
# Teacher Society                                   NaN      NaN     NaN
# Tipu Sultan Road                                  NaN      NaN     NaN
# University Road                                   NaN      NaN     NaN
# Zamzama                                           NaN      NaN     NaN
#
#                                                                         \
#
# Venue Category                            Theme Park Ride / Attraction
# Neighborhood
# Shahrah-e-Pakistan                                                 NaN
# Siraj-ud-Daula Road                                                NaN
# Suparco Road                                                       NaN
# Super Highway                                                      NaN
# Surti Muslim Co-Operative Housing Society                          NaN
# Tariq Road                                                         NaN
# Teacher Society                                                    NaN
# Tipu Sultan Road                                                   NaN
# University Road                                                    NaN
# Zamzama                                                            NaN
#
#                                                                              \
#
# Venue Category                            Toll Booth Transportation Service
# Neighborhood
# Shahrah-e-Pakistan                               NaN                    NaN
# Siraj-ud-Daula Road                              NaN                    NaN
# Suparco Road                                     NaN                    NaN
# Super Highway                                    NaN                    NaN
# Surti Muslim Co-Operative Housing Society        1.0                    NaN
# Tariq Road                                       NaN                    NaN
# Teacher Society                                  NaN                    NaN
# Tipu Sultan Road                                 NaN                    NaN
# University Road                                  NaN                    NaN
# Zamzama                                          NaN                    NaN
#
#                                                               \
#
# Venue Category                            Turkish Restaurant
# Neighborhood
# Shahrah-e-Pakistan                                       NaN
# Siraj-ud-Daula Road                                      NaN
# Suparco Road                                             NaN
# Super Highway                                            NaN
# Surti Muslim Co-Operative Housing Society                NaN
# Tariq Road                                               NaN
# Teacher Society                                          NaN
# Tipu Sultan Road                                         NaN
# University Road                                          NaN
# Zamzama                                                  NaN
#
#                                                                          \
#
# Venue Category                            Vegetarian / Vegan Restaurant
# Neighborhood
# Shahrah-e-Pakistan                                                  NaN
# Siraj-ud-Daula Road                                                 NaN
# Suparco Road                                                        NaN
# Super Highway                                                       NaN
# Surti Muslim Co-Operative Housing Society                           NaN
# Tariq Road                                                          NaN
# Teacher Society                                                     NaN
# Tipu Sultan Road                                                    NaN
# University Road                                                     NaN
# Zamzama                                                             NaN
#
#
#
# Venue Category                            Watch Shop Women's Store
# Neighborhood
# Shahrah-e-Pakistan                               NaN           NaN
# Siraj-ud-Daula Road                              NaN           NaN
# Suparco Road                                     NaN           NaN
# Super Highway                                    NaN           NaN
# Surti Muslim Co-Operative Housing Society        NaN           NaN
# Tariq Road                                       NaN           NaN
# Teacher Society                                  NaN           NaN
# Tipu Sultan Road                                 NaN           NaN
# University Road                                  NaN           NaN
# Zamzama                                          NaN           NaN

# %%
k_df=k_df.reset_index()

# %%
#  Forming a new dataframe with desired venues for our use

df_v=pd.DataFrame(columns=['location','Shopping Mall','Department Store','Bakery','Restaurant','Park','Market','Pharmacy'])

df_v['location']= k_df['Neighborhood']
df_v['Shopping Mall']=k_df['Venue Category','value_counts','Shopping Mall']
df_v['Department Store']=k_df['Venue Category','value_counts','Department Store']
df_v['Bakery']=k_df['Venue Category','value_counts','Bakery']
df_v['Restaurant']=k_df['Venue Category','value_counts','Restaurant']
df_v['Park']=k_df['Venue Category','value_counts','Park']
df_v['Market']=k_df['Venue Category','value_counts','Market']
df_v['Pharmacy']=k_df['Venue Category','value_counts','Pharmacy']

# Getting sum of all the venues in the locality near house
df_v['Total venues']= df_v.iloc[:, -7:-1].sum(axis=1)

df_v.tail(10)
# Out:
#                                       location  Shopping Mall  \
# 96                          Shahrah-e-Pakistan            NaN
# 97                         Siraj-ud-Daula Road            NaN
# 98                                Suparco Road            NaN
# 99                               Super Highway            NaN
# 100  Surti Muslim Co-Operative Housing Society            NaN
# 101                                 Tariq Road            NaN
# 102                            Teacher Society            NaN
# 103                           Tipu Sultan Road            NaN
# 104                            University Road            NaN
# 105                                    Zamzama            1.0
#
#      Department Store  Bakery  Restaurant  Park  Market  Pharmacy  \
# 96                2.0     3.0         NaN   NaN     NaN       NaN
# 97                2.0     NaN         NaN   1.0     1.0       NaN
# 98                NaN     NaN         NaN   NaN     NaN       NaN
# 99                NaN     NaN         NaN   NaN     NaN       NaN
# 100               NaN     NaN         NaN   NaN     NaN       NaN
# 101               NaN     NaN         NaN   NaN     NaN       NaN
# 102               NaN     NaN         NaN   NaN     NaN       NaN
# 103               1.0     1.0         NaN   NaN     NaN       1.0
# 104               NaN     NaN         NaN   NaN     NaN       NaN
# 105               NaN     NaN         NaN   NaN     NaN       NaN
#
#      Total venues
# 96            5.0
# 97            4.0
# 98            0.0
# 99            0.0
# 100           0.0
# 101           0.0
# 102           0.0
# 103           2.0
# 104           0.0
# 105           1.0

# %%
# Sorting on basis of total venues in descending order

df_v = df_v.sort_values(by ='Total venues' , ascending=False)

df_v=df_v.reset_index()
df_v=df_v.drop(['index'],axis=1)
df_v.head(10)
# Out:
#                location  Shopping Mall  Department Store  Bakery  Restaurant  \
# 0    Shahrah-e-Pakistan            NaN               2.0     3.0         NaN
# 1      Maskan Chowrangi            NaN               1.0     2.0         1.0
# 2   Siraj-ud-Daula Road            NaN               2.0     NaN         NaN
# 3                Others            1.0               NaN     NaN         1.0
# 4  Naval Housing Scheme            NaN               NaN     NaN         1.0
# 5             Nazimabad            NaN               1.0     NaN         NaN
# 6       North Nazimabad            NaN               NaN     2.0         1.0
# 7             Hill Park            1.0               NaN     1.0         NaN
# 8   Blue Bell Residency            NaN               NaN     3.0         NaN
# 9      Shahra-e-Qaideen            1.0               NaN     NaN         NaN
#
#    Park  Market  Pharmacy  Total venues
# 0   NaN     NaN       NaN           5.0
# 1   NaN     NaN       NaN           4.0
# 2   1.0     1.0       NaN           4.0
# 3   NaN     1.0       NaN           3.0
# 4   NaN     2.0       1.0           3.0
# 5   1.0     1.0       NaN           3.0
# 6   NaN     NaN       NaN           3.0
# 7   1.0     NaN       NaN           3.0
# 8   NaN     NaN       NaN           3.0
# 9   1.0     NaN       NaN           2.0

# %%
df_v.shape
# Out:
# (106, 9)

# %%
? Removing rows 

df_v=df_v[df_v['Total venues'] != 0.0]

df_v=df_v[~df_v['location'].str.contains('Others')]

df_v.shape
# Out:
# Object ` Removing rows` not found.
# (52, 9)

# %%
df_v5=df_v.head(10)

# %%
df_v5.plot(x="location",kind="bar", fontsize=20,figsize=(20, 5))
# Out:
# <AxesSubplot:xlabel='location'>

# %%
# Merging data frames to add with older dataframe have price and coordinates

df_combined = df_homes

# merge datasets
df_combined = df_v.join(df_combined.set_index('location'), on='location')
df_combined.head(10)
# Out:
#                 location  Shopping Mall  Department Store  Bakery  Restaurant  \
# 0     Shahrah-e-Pakistan            NaN               2.0     3.0         NaN
# 1       Maskan Chowrangi            NaN               1.0     2.0         1.0
# 2    Siraj-ud-Daula Road            NaN               2.0     NaN         NaN
# 4   Naval Housing Scheme            NaN               NaN     NaN         1.0
# 5              Nazimabad            NaN               1.0     NaN         NaN
# 6        North Nazimabad            NaN               NaN     2.0         1.0
# 7              Hill Park            1.0               NaN     1.0         NaN
# 8    Blue Bell Residency            NaN               NaN     3.0         NaN
# 9       Shahra-e-Qaideen            1.0               NaN     NaN         NaN
# 10           DHA Defence            NaN               NaN     1.0         1.0
#
#     Park  Market  Pharmacy  Total venues property_type     city  \
# 0    NaN     NaN       NaN           5.0         House  Karachi
# 1    NaN     NaN       NaN           4.0         House  Karachi
# 2    1.0     1.0       NaN           4.0         House  Karachi
# 4    NaN     2.0       1.0           3.0         House  Karachi
# 5    1.0     1.0       NaN           3.0         House  Karachi
# 6    NaN     NaN       NaN           3.0         House  Karachi
# 7    1.0     NaN       NaN           3.0         House  Karachi
# 8    NaN     NaN       NaN           3.0         House  Karachi
# 9    1.0     NaN       NaN           2.0         House  Karachi
# 10   NaN     NaN       NaN           2.0         House  Karachi
#
#     mean_latitude  mean_longitude    price_mean    price_min    price_max  \
# 0       24.934436       67.072266  1.265000e+08   23000000.0  230000000.0
# 1       24.934847       67.105248  1.160000e+07   11200000.0   12000000.0
# 2       24.879682       67.068985  2.300000e+08  160000000.0  300000000.0
# 4       24.840295       67.057387  7.293821e+07     140000.0  150000000.0
# 5       24.914618       67.029741  3.690564e+07      16000.0  350000000.0
# 6       24.942891       67.046485  4.412318e+07      20000.0  260000000.0
# 7       24.868021       67.071147  3.638095e+07      35000.0   80000000.0
# 8       24.837117       67.035573  6.000000e+06    6000000.0    6000000.0
# 9       24.872849       67.038423  3.537500e+06     700000.0   12000000.0
# 10      24.808753       67.063815  8.094658e+07          1.0  700000000.0
#
#     area_mean  are_min  area_max  bedroom_mean  bedroom_min  bedroom_max  \
# 0    3.000000      1.2       4.8      4.500000            3            6
# 1    4.000000      3.6       4.4      4.000000            4            4
# 2    1.400000      1.0       1.8      2.000000            0            4
# 4   13.464286      1.0      14.0      4.535714            0            8
# 5    8.672146      1.0      19.5      3.351598            0           11
# 6    8.338095      1.0      19.6      3.925025            0           68
# 7    6.166667      1.0      12.0      4.428571            0            7
# 8    4.400000      4.4       4.4      7.000000            7            7
# 9    1.500000      1.2       2.4      4.250000            0           10
# 10   3.541619      1.0      20.0      4.845252            0           15
#
#     total_houses
# 0              2
# 1              2
# 2              2
# 4             28
# 5            219
# 6            987
# 7             21
# 8              1
# 9              4
# 10          5286

# %%
df_combined.plot(x="price_mean", y="Total venues", kind="scatter")
# Out:
# <AxesSubplot:xlabel='price_mean', ylabel='Total venues'>

# %% [markdown]
# ### Hypothesis 1
# Null Hypothesis           𝐻0:  price_mean is not correlated with Total_venues
#
# Alternative Hypothesis    𝐻1:  price_mean is correlated with Total_venues

# %%
import scipy.stats

# %%
scipy.stats.pearsonr(df_combined['price_mean'], df_combined['Total venues'])
# Out:
# (0.3845605883805333, 0.004880352224622747)

# %% [markdown]
# #### Conclusion: Since the p-value < 0.05, we reject the Null hypothesis and conclude that there exists a relationship between price_mean and Total_venues

# %% [markdown]
# ### Hypothesis 2
# Null Hypothesis           𝐻0:  price_mean is not correlated with area_mean
#
# Alternative Hypothesis    𝐻1:  price_mean is correlated with area_mean

# %%
df_combined.plot(x="price_mean", y="area_mean", kind="scatter")
# Out:
# <AxesSubplot:xlabel='price_mean', ylabel='area_mean'>

# %%
scipy.stats.pearsonr(df_combined['price_mean'], df_combined['area_mean'])
# Out:
# (0.05193646097101594, 0.7146173762718203)

# %% [markdown]
# #### Conclusion: Since the p-value > 0.05, we accept the Null hypothesis and conclude that there exists no relationship between price_mean and area_mean

# %% [markdown]
# ### Hypothesis 3
# Null Hypothesis           𝐻0:  price_mean is not correlated bedroom_mean
#
# Alternative Hypothesis    𝐻1:  price_mean is correlated with bedroom_mean

# %%
df_combined.plot(x="price_mean", y="bedroom_mean", kind="scatter")
# Out:
# <AxesSubplot:xlabel='price_mean', ylabel='bedroom_mean'>

# %%
scipy.stats.pearsonr(df_combined['price_mean'], df_combined['bedroom_mean'])
# Out:
# (-0.033782528434371864, 0.812070976289614)

# %% [markdown]
# #### Conclusion: Since the p-value > 0.05, we accept the Null hypothesis and conclude that there exists no relationship between price_mean and bedroom_mean

# %%
sort_area = df_combined.sort_values(by ='area_mean' , ascending=False)
sort_area.head()
# Out:
#                  location  Shopping Mall  Department Store  Bakery  \
# 19     Darul Aman Society            NaN               1.0     NaN
# 41      Allama Iqbal Town            NaN               NaN     NaN
# 4    Naval Housing Scheme            NaN               NaN     NaN
# 25                Zamzama            1.0               NaN     NaN
# 30  Khalid Bin Walid Road            NaN               1.0     NaN
#
#     Restaurant  Park  Market  Pharmacy  Total venues property_type     city  \
# 19         NaN   1.0     NaN       NaN           2.0         House  Karachi
# 41         NaN   NaN     1.0       NaN           1.0         House  Karachi
# 4          1.0   NaN     2.0       1.0           3.0         House  Karachi
# 25         NaN   NaN     NaN       NaN           1.0         House  Karachi
# 30         NaN   NaN     NaN       NaN           1.0         House  Karachi
#
#     mean_latitude  mean_longitude    price_mean   price_min    price_max  \
# 19      24.875484       67.068230  1.400000e+08  70000000.0  180000000.0
# 41      24.926879       67.026472  8.000000e+07  80000000.0   80000000.0
# 4       24.840295       67.057387  7.293821e+07    140000.0  150000000.0
# 25      24.822799       67.040011  1.005878e+08    195000.0  460000000.0
# 30      24.874922       67.057322  4.392111e+07     40000.0  100000000.0
#
#     area_mean  are_min  area_max  bedroom_mean  bedroom_min  bedroom_max  \
# 19  16.066667     10.0      19.2      8.333333            5           11
# 41  16.000000     16.0      16.0      6.000000            6            6
# 4   13.464286      1.0      14.0      4.535714            0            8
# 25  10.189744      1.0      14.0      4.692308            0            7
# 30  10.155556      1.2      16.0      5.444444            0           10
#
#     total_houses
# 19             3
# 41             1
# 4             28
# 25            39
# 30             9

# %%
sort_area_20 = df_combined.sort_values(by ='area_mean' , ascending=False).head(20)
sort_area_20.head()
# Out:
#                  location  Shopping Mall  Department Store  Bakery  \
# 19     Darul Aman Society            NaN               1.0     NaN
# 41      Allama Iqbal Town            NaN               NaN     NaN
# 4    Naval Housing Scheme            NaN               NaN     NaN
# 25                Zamzama            1.0               NaN     NaN
# 30  Khalid Bin Walid Road            NaN               1.0     NaN
#
#     Restaurant  Park  Market  Pharmacy  Total venues property_type     city  \
# 19         NaN   1.0     NaN       NaN           2.0         House  Karachi
# 41         NaN   NaN     1.0       NaN           1.0         House  Karachi
# 4          1.0   NaN     2.0       1.0           3.0         House  Karachi
# 25         NaN   NaN     NaN       NaN           1.0         House  Karachi
# 30         NaN   NaN     NaN       NaN           1.0         House  Karachi
#
#     mean_latitude  mean_longitude    price_mean   price_min    price_max  \
# 19      24.875484       67.068230  1.400000e+08  70000000.0  180000000.0
# 41      24.926879       67.026472  8.000000e+07  80000000.0   80000000.0
# 4       24.840295       67.057387  7.293821e+07    140000.0  150000000.0
# 25      24.822799       67.040011  1.005878e+08    195000.0  460000000.0
# 30      24.874922       67.057322  4.392111e+07     40000.0  100000000.0
#
#     area_mean  are_min  area_max  bedroom_mean  bedroom_min  bedroom_max  \
# 19  16.066667     10.0      19.2      8.333333            5           11
# 41  16.000000     16.0      16.0      6.000000            6            6
# 4   13.464286      1.0      14.0      4.535714            0            8
# 25  10.189744      1.0      14.0      4.692308            0            7
# 30  10.155556      1.2      16.0      5.444444            0           10
#
#     total_houses
# 19             3
# 41             1
# 4             28
# 25            39
# 30             9

# %%
sort_venues = df_combined.sort_values(by ='Total venues' , ascending=False)

# %%
sort_venues_20 = df_combined.sort_values(by ='Total venues' , ascending=False).head(20)
sort_venues_20.head()
# Out:
#                location  Shopping Mall  Department Store  Bakery  Restaurant  \
# 0    Shahrah-e-Pakistan            NaN               2.0     3.0         NaN
# 2   Siraj-ud-Daula Road            NaN               2.0     NaN         NaN
# 1      Maskan Chowrangi            NaN               1.0     2.0         1.0
# 4  Naval Housing Scheme            NaN               NaN     NaN         1.0
# 5             Nazimabad            NaN               1.0     NaN         NaN
#
#    Park  Market  Pharmacy  Total venues property_type     city  mean_latitude  \
# 0   NaN     NaN       NaN           5.0         House  Karachi      24.934436
# 2   1.0     1.0       NaN           4.0         House  Karachi      24.879682
# 1   NaN     NaN       NaN           4.0         House  Karachi      24.934847
# 4   NaN     2.0       1.0           3.0         House  Karachi      24.840295
# 5   1.0     1.0       NaN           3.0         House  Karachi      24.914618
#
#    mean_longitude    price_mean    price_min    price_max  area_mean  are_min  \
# 0       67.072266  1.265000e+08   23000000.0  230000000.0   3.000000      1.2
# 2       67.068985  2.300000e+08  160000000.0  300000000.0   1.400000      1.0
# 1       67.105248  1.160000e+07   11200000.0   12000000.0   4.000000      3.6
# 4       67.057387  7.293821e+07     140000.0  150000000.0  13.464286      1.0
# 5       67.029741  3.690564e+07      16000.0  350000000.0   8.672146      1.0
#
#    area_max  bedroom_mean  bedroom_min  bedroom_max  total_houses
# 0       4.8      4.500000            3            6             2
# 2       1.8      2.000000            0            4             2
# 1       4.4      4.000000            4            4             2
# 4      14.0      4.535714            0            8            28
# 5      19.5      3.351598            0           11           219

# %%
sort_bedrooms= df_combined.sort_values(by ='bedroom_mean' , ascending=False)

# %%
sort_bedrooms_20= df_combined.sort_values(by ='bedroom_mean' , ascending=False).head(20)
sort_bedrooms_20.head()
# Out:
#                location  Shopping Mall  Department Store  Bakery  Restaurant  \
# 19   Darul Aman Society            NaN               1.0     NaN         NaN
# 8   Blue Bell Residency            NaN               NaN     3.0         NaN
# 32          Old Clifton            1.0               NaN     NaN         NaN
# 41    Allama Iqbal Town            NaN               NaN     NaN         NaN
# 42       Chapal Skymark            NaN               NaN     1.0         NaN
#
#     Park  Market  Pharmacy  Total venues property_type     city  \
# 19   1.0     NaN       NaN           2.0         House  Karachi
# 8    NaN     NaN       NaN           3.0         House  Karachi
# 32   NaN     NaN       NaN           1.0         House  Karachi
# 41   NaN     1.0       NaN           1.0         House  Karachi
# 42   NaN     NaN       NaN           1.0         House  Karachi
#
#     mean_latitude  mean_longitude   price_mean   price_min    price_max  \
# 19      24.875484       67.068230  140000000.0  70000000.0  180000000.0
# 8       24.837117       67.035573    6000000.0   6000000.0    6000000.0
# 32      24.817883       67.032915   22940000.0    400000.0  110000000.0
# 41      24.926879       67.026472   80000000.0  80000000.0   80000000.0
# 42      24.844343       67.027389   42500000.0  42500000.0   42500000.0
#
#     area_mean  are_min  area_max  bedroom_mean  bedroom_min  bedroom_max  \
# 19  16.066667     10.0      19.2      8.333333            5           11
# 8    4.400000      4.4       4.4      7.000000            7            7
# 32   2.060000      1.0       4.0      6.000000            0           11
# 41  16.000000     16.0      16.0      6.000000            6            6
# 42  10.000000     10.0      10.0      6.000000            6            6
#
#     total_houses
# 19             3
# 8              1
# 32             5
# 41             1
# 42             1

# %%
sv20=sort_venues_20[['location']].copy()

sa20=sort_area_20[['location']].copy()

sb20=sort_bedrooms_20[['location']].copy()

# %%
# merging the 3 dataframes on location to find which location has all 3 most venues, bedrooms and larger area size
msav20 = pd.merge(sa20, sv20, on=['location'], how='inner')

msavb20 = pd.merge(msav20,sb20, on=['location'], how='inner')

msavb20
# Out:
#                location
# 0    Darul Aman Society
# 1  Naval Housing Scheme
# 2          Gulberg Town

# %%
df_selected = msavb20.join(df_combined.set_index('location'), on='location')
df_selected
# Out:
#                location  Shopping Mall  Department Store  Bakery  Restaurant  \
# 0    Darul Aman Society            NaN               1.0     NaN         NaN
# 1  Naval Housing Scheme            NaN               NaN     NaN         1.0
# 2          Gulberg Town            NaN               NaN     1.0         1.0
#
#    Park  Market  Pharmacy  Total venues property_type     city  mean_latitude  \
# 0   1.0     NaN       NaN           2.0         House  Karachi      24.875484
# 1   NaN     2.0       1.0           3.0         House  Karachi      24.840295
# 2   NaN     NaN       NaN           2.0         House  Karachi      24.924467
#
#    mean_longitude    price_mean   price_min    price_max  area_mean  are_min  \
# 0       67.068230  1.400000e+08  70000000.0  180000000.0  16.066667     10.0
# 1       67.057387  7.293821e+07    140000.0  150000000.0  13.464286      1.0
# 2       67.067157  2.531250e+07   2400000.0   75000000.0   7.118750      1.5
#
#    area_max  bedroom_mean  bedroom_min  bedroom_max  total_houses
# 0      19.2      8.333333            5           11             3
# 1      14.0      4.535714            0            8            28
# 2      16.0      4.750000            0           10            48

# %%
df_selected.plot(x="location", y=["Total venues", "area_mean","bedroom_mean"], kind="bar")
# Out:
# <AxesSubplot:xlabel='location'>
